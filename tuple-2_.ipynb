# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %% [markdown]
# # tuple

# %% [markdown]
# any where we have a fixed size of collection there we use tuple.bcoz tuple never support append operation,extend op,insert op,as it immutable entity.

# %% [markdown]
# .for data security we use tuple so that anyone cant perform any operation .operation wise tuple same as list except append and extend and insert .

# %%
t=(1,44,4343,455,(2242,244,43),"sudh")

# %% [markdown]
# tuple inside a tuple called nested tuple

# %%
t
# Out:
# (1, 44, 4343, 455, (2242, 244, 43), 'sudh')

# %%
t1=([232,354545,53],("wdwf",334,44.4),"sufdh")

# %%
t1
# Out:
# ([232, 354545, 53], ('wdwf', 334, 44.4), 'sufdh')

# %%
t1[0][1]="sudh"

# %%
t1
# Out:
# ([232, 'sudh', 53], ('wdwf', 334, 44.4), 'sufdh')

# %% [markdown]
# immutable-we cant make change ata particular index.

# %%
t1[0]="sukumar"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5184a9f0f848> in <module>
# ----> 1 t1[0]="sukumar"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# here at 0 th index there is a list which is a mutable entity so we can perform an item reassignment operation.but t1[0] cant be replaced.

# %% [markdown]
# .list can hold tuple and viceversa.and tuple to list is possible and vicevsersa.

# %%
t1
# Out:
# ([232, 'sudh', 53], ('wdwf', 334, 44.4), 'sufdh')

# %%
l=list(t1)

# %%
l
# Out:
# [[232, 'sudh', 53], ('wdwf', 334, 44.4), 'sufdh']

# %%
tuple(l)
# Out:
# ([232, 'sudh', 53], ('wdwf', 334, 44.4), 'sufdh')

# %% [markdown]
# # set function and operations

# %%
l=[1,2,3,4,5,6,76,5,5,5,5,5,2,3,4,5,6,5,6,6,4,3,3]

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6, 76}

# %% [markdown]
# set funcn able to remove the duplicate.
# in case of set notation is curly bases notation.

# %%
s={}

# %%
type(s)
# Out:
# dict

# %% [markdown]
# dictonary

# %%
s1={22,33,3}

# %%
type(s1)
# Out:
# set

# %%
s2={1,1,1,1,2,2,3,3,4,5,54,542}

# %%
s2
# Out:
# {1, 2, 3, 4, 5, 54, 542}

# %% [markdown]
# remove all the duplicate element.

# %%
s2
# Out:
# {1, 2, 3, 4, 5, 54, 542}

# %%
s2[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ab7c8e26b0d3> in <module>
# ----> 1 s2[0]
#
# TypeError: 'set' object does not support indexing

# %%
list(s2)
# Out:
# [1, 2, 3, 4, 5, 54, 542]

# %%
list(s2)[0]
# Out:
# 1

# %%
s2.add(13131)

# %%
s2
# Out:
# {1, 2, 3, 4, 5, 54, 542, 13131}

# %%
s2.add("Sudh")

# %%
s2
# Out:
# {1, 13131, 2, 3, 4, 5, 54, 542, 'Sudh'}

# %%
s2.add([23,434,4])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f126fe65f128> in <module>
# ----> 1 s2.add([23,434,4])
#
# TypeError: unhashable type: 'list'

# %%
{[233,3,2,2,2,2],23,32,45,4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6f43f59526dc> in <module>
# ----> 1 {[233,3,2,2,2,2],23,32,45,4}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# set holds a unordered collection of unique element .it will try to find out the uniqueness inbtween the premetive data type not inbetween the collection.

# %%
{(23,232,23),353,3234}
# Out:
# {(23, 232, 23), 3234, 353}

# %% [markdown]
# set allows to host immutable elements inside it.

# %%
{(1,2,2,3),(1,2,2,3),3,3,3,5,5,5,5,213,756}
# Out:
# {(1, 2, 2, 3), 213, 3, 5, 756}

# %% [markdown]
# # set operations

# %% [markdown]
# set is an unorderes collection.

# %%
s={(1,2,2,3),(1,2,2,3),3,3,3,5,5,5,5,213,756}

# %%
s
# Out:
# {(1, 2, 2, 3), 213, 3, 5, 756}

# %%
s.remove(3)

# %%
s
# Out:
# {(1, 2, 2, 3), 213, 5, 756}

# %% [markdown]
# 3 removed from the set, so it is remove operation.

# %%
s.discard(5)

# %%
s
# Out:
# {(1, 2, 2, 3), 213, 756}

# %%
s.remove(45)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-30b5ee21a9a0> in <module>
# ----> 1 s.remove(45)
#
# KeyError: 45

# %%
s.discard(45)

# %%
s
# Out:
# {(1, 2, 2, 3), 213, 756}

# %% [markdown]
# .set is neither mutable nor immutable .it is an unordered collection so wont be able to get an index so cant do any manipulation operations.

# %%
{"sudh","sudh"}
# Out:
# {'sudh'}

# %%
{"Sudh","sudh"}
# Out:
# {'Sudh', 'sudh'}

# %% [markdown]
# set is case sensetive.
# to reverse set convert it to list then reversrse it

# %%
s
# Out:
# {(1, 2, 2, 3), 213, 756}

# %%
d=list(s)

# %%
d.reverse()

# %%
d
# Out:
# [756, 213, (1, 2, 2, 3)]

# %% [markdown]
# # Dictionary element

# %%
s
